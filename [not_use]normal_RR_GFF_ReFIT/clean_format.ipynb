# %% [markdown]
# # Format Results
#
# 轉成指定的 `jsonl` 格式，並依 `refit_rank` 排序。

# %%
from __future__ import annotations

import json
from pathlib import Path

INPUT_PATH = Path("/workplace/dxlin/Homework/IR/normal_RR_GFF_ReFIT/outputs/qwen_gff_refit_results.json")
OUTPUT_PATH = Path("/workplace/dxlin/Homework/IR/normal_RR_GFF_ReFIT/query2_result.jsonl")
TOP_K = 30


def build_record(raw_item: dict, item_id: int) -> dict:
    sorted_answers = sorted(
        raw_item.get("refit_results", []),
        key=lambda answer: answer.get("refit_rank", float("inf")),
    )[:TOP_K]

    return {
        "id": item_id,
        "question": raw_item.get("query", ""),
        "answers": [
            {
                "id": answer.get("doc_id", ""),
                "text": answer.get("answer", ""),
            }
            for answer in sorted_answers
        ],
    }


raw_data = json.loads(INPUT_PATH.read_text(encoding="utf-8"))
formatted_records = [build_record(item, idx) for idx, item in enumerate(raw_data, start=1)]

with OUTPUT_PATH.open("w", encoding="utf-8") as output_file:
    for record in formatted_records:
        output_file.write(json.dumps(record, ensure_ascii=False) + "\n")

print(f"Wrote {len(formatted_records)} records to {OUTPUT_PATH}")
formatted_records[0]
# Out:
# Wrote 10 records to /workplace/dxlin/Homework/IR/normal_RR_GFF_ReFIT/query2_result.jsonl
# {'id': 1,
#  'question': '當家人出現情緒失控、妄想、多疑或行為異常等情形時，家屬應如何協助就醫或處理？',
#  'answers': [{'id': '8d9f2cee',
#    'text': '您好.家人的精神問題還是以鼓勵醫療為主.暫時先由長輩們判斷.至於您與家人相處上的困難以及來信提到:(我也覺得自己有點問題)的部分.建議可至醫療院所就診諮商.或可撥打衛福部(1925)安心專線告訴您的困擾.會有專業人員提供輔導轉介等服務.應有助益.'},
#   {'id': 'dd22c001', 'text': '強迫治療較好'},
#   {'id': 'ab7e826d',
#    'text': '你好本院居家治療團隊有豐富的社區個案治療經驗可提供到府訪視會談並安排後續治療計畫但若有嚴重內科問題應先到綜合醫院檢查治療電話8630204126101660#325'},
#   {'id': '8ebd4674',
#    'text': '你好辛苦了你真是堅強要忍受這麼多的無奈以你描述的病情應該可以安排她住慢性(復健)病房治療幾個月以提升療效建立病識感有關屏東的醫院資源可以上網http://chs-www.doh.gov.tw/csnpt/index.html點選右下方精神照護專責醫院查詢打去醫院確定就醫及慢性病房住院流程通常安排速度滿快的祝順利'},
#   {'id': '34903580',
#    'text': '本院有居家治療團隊，醫師及護士可安排去家裡對疑似病患進行評估鑑定，服務電話：86302041，專責護士將與你討論安排細節。加油！希望你父親盡快接受治療及康復。'},
#   {'id': 'e1446f91',
#    'text': '行政院衛生署台南醫院精神科王崇仁醫師敬覆您好：精神病患若有就醫困難，尤其有造成社區家庭困擾或自傷傷人之虞者，皆可聯絡本市衛生局醫政課陳正昇先生(TEL:2679751轉3207醫政課)他會盡力協助的。又病患若有自傷傷人之虞者依法需強制就醫，當地之警察局或119皆有義務協助就醫。署立台南醫院祝您身體健康•萬事如意！！'},
#   {'id': '75c83165',
#    'text': '行政院衛生署台南醫院精神科張訓誠醫師回覆親愛的老杜您好：若按照您所說的情形，令弟已出現暴力（傷人行為），則可向當地警察機關申請協助送醫。送到附近大醫院精神科急診，再由專業人員鑑定，是否需要住院治療。精神科中，重大疾病病患多數沒有病識感（就是認為自己沒有病），要他們主動就醫相常困難。常常要一大群家屬、朋友協同119人員或警察先生們，軟硬兼施下，才會被帶到精神科來就診。即使住院治療一陣子有了起色，出院回家後，又往往服藥順從性不佳(即不吃藥)而又再發病，又得勞師動眾一番。經歷一番醫療，慢慢地才多少能為病患建立起病識感。建議您先與家屬們商量好，確定令弟在何處，再通知警察先生們，請求協助送醫。儘早醫療，效果及預後會較好。祝一切順利。台南醫院祝您身體健康•萬事如意！！'},
#   {'id': 'e0e6e736', 'text': '網友好如果每個月仍都有打針仍不穩定，確實有可能藥物還需調整，要再和她的醫師討論。吳恩亮醫師'},
#   {'id': 'd29c5c26',
#    'text': '您好若是您找她過去就診的醫師，病歷上會有她過去的症狀及治療史，加上您的敘述以及影片的補充，和醫師討論治療方法，應該是可以嘗試的方式。'},
#   {'id': '6e1bc72b',
#    'text': '你好：媽媽有這樣的狀況，想必家人都很擔心，也很苦惱不知道該怎麼幫忙她，若是突然發生的精神症狀，可能要先排除身體(如甲狀腺功能)或大腦病灶的可能性，建議先做一般檢查及腦部影像檢查，若檢查無異常再懷疑是精神疾病。就醫方式建議儘量以商量或引導的方式協助就醫，透過傾聽媽媽的不舒服，同理心反應，透過她身體的不舒服作為引線，引導至醫院精神科門診就醫。另外，若有緊急狀況，例如出現傷人或自傷行為之虞，在此時保持傾聽的態度先了解她行為的原因，不要激怒她，在盡量減少任何人受傷的前提下，勸服或啟動緊急護送就醫機制，尋求警消人員、衛生所公衛護理師的協助，護送至精神科專科醫院急診室緊急就醫。希望有回答到你的問題:)'},
#   {'id': '31229570',
#    'text': '酷酷你好:Q1:適應障礙、憂鬱症、妄想症、思覺失調都有可能，必須要進一步評估才有辦法確認。Q2:可問問看是否有失眠、記憶衰退、頭痛頭暈等症狀，以治療這些身體症狀的理由來說服就醫通常較容易被接受。Q3:建議聆聽理解，提供情緒支持。也可轉移注意力，或邀請一起進行其他健康的活動。'},
#   {'id': 'cec663a7',
#    'text': '依照目前精神醫療法規，嚴重精神病人，而有自傷傷人可能性時，卻又不肯就醫，可以申請強制治療，由各地審查委員會審查，審查通過後可以強制醫療。如果您舅舅有行為上的異常，擔心會傷害自己或他人時就可以送到醫院急診，由急診醫師判斷填寫相關表格送審。'},
#   {'id': '6a9f14d9',
#    'text': '小P網友您好：由您的描述大略可知，您家中可能有名妄想型精神分裂症的病友，而他的症狀涵蓋了正性(妄想等)及負性(如生活習慣退化)症狀。治療的必要性大概包含兩大原因:避免症狀起伏惡化，成為社會上常說的「不定時炸彈」；另外遏止他已經出現的退化現象(不然以後會很難照顧)。我是著回答您的問題如下：1.如果有機會與途徑，精神科是有一種所謂的居家治療，可以到府探視病患，提供醫療的可能性；另外也有人選擇患者較不容易察覺的滴劑，使用，改善患者的現實感，再透過直接或間接病識感的建立，達成長期治療的共識；找得到有力人士可勸得動您的婆婆嗎？2.環境固然會影響幼童的發展，但重點還是看教育上能發揮多大力量，所以古代既有孟母三遷，也有出淤泥而不染的講法不是嗎？3.一般而言，精神病的患者自我的強度不是很好，催眠通常反而容易導致崩潰，並不太受推薦；精神病是腦內神經傳導物質失去平衡，藥物治療幾乎是必要的，其他治療則是輔助性而已。4.健康的照顧者是精神病患最大的支柱，所以家屬應能夠培養與患者相處、危機處理、自我壓力調適等技巧。可以透過與精神醫療團隊的勾同學習、加入康復之友協會，或閱讀相關書籍(如成大楊延光醫師所著「杜鵑窩的春天」)加以充實。祝早日解開這個死結'},
#   {'id': '4dbdd592',
#    'text': '您好!因患者有明顯精神病症狀且無病識感,現己有自我傷害之行為,依精神衛生法,可請警察機關協助送醫。行政院衛生署桃園醫院身心內科謝青宙醫師敬覆'},
#   {'id': 'c633f73d',
#    'text': '你好：建議先跟住家附近的衛生所諮詢，可申請醫師居家鑑定(某些縣市有專責醫院及補助)，或是公衛護理師先至家中關懷；若個案出現傷人或自傷企圖或行為，可打110或119，尋求警消人員的協助來啟動強制就醫。也可以請個案比較信服的長輩或朋友協助建立個案病識感，儘量以商量或引導的方式協助就醫，透過傾聽個案的不舒服，同理反應對方，透過個案身體的不舒服作為引線，引導個案至精神科專科醫院就醫。希望有回答到你的問題:)'},
#   {'id': '4f83204f',
#    'text': '您好，根據您的描述，有下列幾點說明：1.精神疾病的診斷範圍其實是很廣泛的，但需要從多個面向來評估才能確定是否達到診斷的標準，其中一項很重要的依據是個人出現的這些狀況，會不會影響到日常生活或工作的能力。2.以您父親而言，不知他出現的狀況有無影響到他的工作狀況？或者他的狀況是一直都是如此或是呈現週期性的變化？因為如果對工作、生活能力沒影響，且一直以來都是如此，就很難診斷有什麼明顯的精神疾病。但也非他就沒問題，或許個性不好，是一個通俗的解釋。3.至於母親，看來生活上已有不小的壓力，會有因為壓力導致的情緒反應也是很合理的，就您陳述的狀況，也無法診斷她有什麼特定的精神疾病。4.建議您可以將您感受到的狀況，嘗試和家人討論看看，如和父親談論曾「在眾人面前打我巴掌」讓您如何不適，看看父親的說法，也許他也可以從中發覺自已行為上的失當，有自我修正的機會。5.您就醫時，也可以和醫師談看看，應該也可以得到適當的建議。以上，祝平安'},
#   {'id': '67189791', 'text': '建議您如實告知主治醫師，謝謝。祝健康~'},
#   {'id': '476ba750',
#    'text': '從你的�躑z來看，你的懷疑確有可能。要讓他從自願就醫到建立病識感是一條漫長的路，我想誠實而委婉的告訴他需要做一些腦部檢查及測驗是必須的。有些醫院有巡迴醫療服務，可請醫師先去診視，如確有需要，在湯水中加藥可為初步處理。'},
#   {'id': '342c77ba',
#    'text': '您好：就您描述您家人，很可能有幻覺及妄想等等思覺失調的精神症狀。建議由家人共同勸導可以就近到精神科掛門診或急診，讓精神科醫師幫忙做相關的評估及治療的轉介即可。若協助送醫有困難，可請求119或110由警消人員協助。以上回答希望有幫助，謝謝您的發問。'},
#   {'id': '73fb38d9',
#    'text': '你好居家訪視是指醫師護士前往家中會談,有時我們用迂迴的理由拜訪,先與個案建立信任感,再設法說服個案就醫等精神症狀發病就好比氣喘病等到很喘了才治療,較難治療,也較不容易完全復原,所以盡快治療是重要的衛生所都有專責護士負責精神病患的管理,他們都非常有專業經驗處理,所以只要告知個案相關資料即可,他們會跟你詳細討論計畫,他們應該也可提供當地是否有居家訪視資源的資料,盡快打電話到衛生所!祝順利'},
#   {'id': '91dbf5d8',
#    'text': '親愛的小蒨：很抱歉！過去二個月因公務較多，疏於回信。單憑妳的描述，我無法斷定妳的母親是否有精神疾病，但看起來妳的母親的一些行為與固著的想法已經令妳和姊妹們相當的困擾！┴以或許可以找一位令堂較相信的親友，江你們的困擾告訴他〈她〉，請其協助溝通，甚至陪同令堂一起前往精神醫療院所接受評估。也可以試著以關懷及同理的方式與令堂溝通，例如：『媽媽，我們瞭解妳對爸爸過去一些不好的行為感到生氣、難以忘懷。但是你的一些言行讓我們感到擔心與害怕，我們希望能陪妳一起接受心理諮詢，一起將過去的結打開。』當然，如果令堂的行為已經出現精神衛生法上所說的『有自傷傷人的行為或之虞』，或者『無法處理自身之事務』，嚴重造成困擾與威脅，建議請你們住家所在地的衛生所公共衛生護士協管區警察或消防人員協助，以較強制的方式送往衛生署指定辦理「強制鑑定與強制住院」的精神醫療院所接受專科醫師的評估與必要的處置！再一次為延遲回覆致歉！祝平安喜樂、一切順利！'},
#   {'id': '3ab02362',
#    'text': '您好.可先試著表示您本人想要就診身心科諮詢.希望家人可以陪同.到時候再順道跟醫師提及家人的問題看如何改善.用此方法試試看.謝謝'},
#   {'id': '93a3f9cc',
#    'text': '致發問網友：您好！您的媽媽疑是精神分裂症病患，應該請您家人一起勸誘媽媽配合就醫，以接受進一步的診療。在屏東您可以到衛生署屏東醫院精神科尋求專業協助。祝一切順利！黃韋欽醫師敬上'},
#   {'id': 'f5c64398',
#    'text': 'shin,你好：看來他極有可能得了「老年性精神病」，確實需要就醫治療。倒是不用那麼麻煩提出告訴。有「精神病，且自傷傷人之虞或行為」就可強制就醫。精神衛生法明文規定，警察機關有協助家屬將病患強制就醫的「義務」。若發生自傷、傷人行為，就可以報警請求協助強制就醫。問題出在你爺爺並未讓醫師診斷過罹患「精神病」，在沒有所謂「自傷傷人行為」情況下，可能警消協助就醫會有疑問。另一個方式，就是請居住所在地「衛生所」「公衛護士」先到你家做評估，然後請公衛護士協助就醫（填寫「疑似精神病患護送鑑定及就醫通報單」，然後拿到精神科醫院請醫師協助）、或直接協助強制就醫。以上假如還有問題...比如說，警消、公衛護士礙於程序問題，無法協助時，可以直接到醫院找醫師討論是否安排「居家治療」或其他治療模式。突然要強制剝奪一個人的自由，確實程序方面很麻煩。但是你可以就上述所描述，在沒有「行為」出現時，先往兩個方向尋求協助----到衛生所找公衛護士、到醫院找精神科醫師。謝謝來信！'},
#   {'id': 'aae47476',
#    'text': '您好：健保所給付的「居家治療」對象，的確只針對經確定診斷後，開立「重大傷病卡」的病患。而您母親目前似乎還無法到診，我們也無法單憑有「被害的想法」就確定診斷，也就是說，居家治療目前並不適用於您母親的狀況。以下有幾個作法建議：1.以您母親較可以接受的理由來看診：例如一般精神疾病常有「失眠」困擾，或是一般中老年婦女常有「頭痛」、「身體酸痛」、「胸悶」等抱怨，可以藉此帶她到一般綜合醫院身心科（其實是精神科，如：署立桃園醫院）。用這些或許她較關心的不舒服為理由，告訴她可以尋求協助，可以讓他感受到家人的關心，願意求醫，也可以避免您把滴劑藥物滴在食物中的掙扎。我們通常會在看診時，針對此類病患盡量用他們可以接受的語言來說明他的病情。2.聯絡（通報）衛生所的公衛護士：公衛護士通常會先與您討論狀況，再決定要不要訪視您母親，不會貿然前往。如果您母親仍然十分堅決拒絕治療，可以透過公衛護士與本院居家護士的連繫，討論後續的治療安排。目前與本院有合作關係的鄉鎮市包括：桃園、中壢、八德、楊梅、蘆竹、龜山、平鎮等七處。另外，桃園縣有的鄉鎮衛生所醫師其實也提供初步的精神科診斷與藥物治療，「到衛生所看病」也許是較能接受的方式。3.如果以上都行不通，萬不得已要用滴劑，則請您與建議您買滴劑的醫師討論用藥劑量，因為，有效的治療劑量常需要一邊治療一邊調整才可以達到。若藉由此方式，也需要在她稍穩定時，找一個她可以接受的理由帶她前來看診（如第1點所寫）。不過，因為您母親的診斷尚未十分確定，是否持續使用滴劑則需要慎重考慮。照顧精神病患的家屬是十分辛苦的過程，以上幾點建議，也還請您多與其他家人充分溝通，一旦決定帶她就醫，也需要家人態度一致才能讓她持續接受治療。希望以上內容能對您有幫助。'},
#   {'id': '66dbc2d1',
#    'text': 'mike,你好：根據你這次的描述，我倒是覺得，比較像是環境壓力因素，加上本身多疑個性，所引起的環境適應障礙，不見得一定是妄想病。確切診斷，還是得臨床評估。建議你跟他好好討論，表達你的關心，也適度的表達你的感受，你可以跟他談，感覺他最近心情不好，你很擔心繼續這樣下去，他身體比如血壓、還有睡眠等都會受到影響，連帶的你也會很擔心，也會受影響，整個家庭都會受影響，因為他心情不好，你也心情不好，你想陪他一起看「心理醫師」（視情況，不排除兩個人都看），並讓他瞭解不是當他精神病，而是想找醫師諮詢，看能否得到壓力調適的方式，藉此改善家庭整體生活狀況。謝謝來信！'},
#   {'id': '7330d67f',
#    'text': 'A1:如果勸不動，有自傷傷人危險的病人在發生狀況時一定要報警處理A2:警察會協助處理A3:有需要A4:安不安全並非醫療問題，請警察協助處理A5:每家醫院不一樣'},
#   {'id': '2c187018',
#    'text': '敬啟者患者不願就醫是經常會發生的狀況我想家人很辛苦又很擔心的因為父親已經“異常亢奮又有拿刀砍自己的手……”已經達到護送就醫的要件我會建議請求公部門的協助送醫您可以聯絡住家所在的衛生所或直接聯絡消防隊的救護車護送父親到本院的急診送達至急診後我們會勸說其接受住院治療如果父親本人不同意還可以考慮申請強制住院治療以確保父親的身體及心理健康也可以讓家人安心以上回覆敬祝身心健康嘉南療養院一般精神科張芳榮上'},
#   {'id': '11a9d2fa',
#    'text': '妳好：躁症發作的病人，是不大可能有病識感的，自然也不會想要接受治療。對他們而言，這種躁症的狀態會讓他們自我感覺良好，他們不可能會願意離開這樣的狀態的。妳可以做的，是先了解他在這樣的狀態中，是否有碰到甚麼困擾。例如花錢花太兇以至於欠債還不出來，或是做事很魯莽以至於闖禍，然後再以幫他改善這些情況為理由，來勸他到醫院跟醫師聊聊。他如果要回去工作，妳可以先跟他的公司聯絡，說明他的情況，希望公司先不要讓他復職。至於妳說的虛幻的想像，指的應該就是躁症病人常有的妄想。對於妄想，建議妳就順著他，不要與他辯駁，因為這是疾病的症狀，不可能透過單純的辯論而讓他改善的。最後，若他不肯就醫，妳可以連絡他住處附近的衛生所，申請由醫師到府來評估他的狀況。衛生所的護理師會先去訪視，若覺得有需要，會再請精神科醫師到家裡訪視。這樣就可以由專業的醫師來評估，並決定下一步的治療方向。祝平安健康！'},
#   {'id': 'ce0c0648',
#    'text': '小女兒，你好：照你來信所描述，令尊所患應為「妄想症」分類中的「嫉妒妄想症」，嫉妒的意思就是「忠貞」。妄想症病人，不用指望他會主動就醫，更別談心理輔導或治療，至於藥物治療，也必須每天吃，等個至少半個月才會見效，而且要持續吃藥才會有效。精神科是個非常特別的科，非意願的封閉式住院治療，等同侵犯人身自由，所以無論警察、醫師等，都會小心處置。在個案未出現攻擊暴力行為或傾向、自殺行為或傾向的情況下，無法強迫他接受治療。所以只有等他出現問題時，報警處理，強制送醫。然而在這之前，你可以先到衛生所尋求「公衛護士」協助，先建立一些基本資料，方便日後強制送醫。謝謝來信！'}]}
